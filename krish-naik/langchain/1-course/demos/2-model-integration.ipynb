# %% [markdown]
# ### Models Integration With OpenAI

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
from langchain.chat_models import init_chat_model

# openAI GPT-4o model
model = init_chat_model("gpt-4o")
model
# Out:
# ChatOpenAI(profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x112ccef90>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x112ccfa10>, root_client=<openai.OpenAI object at 0x112ccc1a0>, root_async_client=<openai.AsyncOpenAI object at 0x112ccf770>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
# invoke the model
response = model.invoke("What is Agents in AI")
response.content
# Out:
# 'In AI, "agents" refer to entities that perceive their environment through sensors and act upon that environment through actuaries or effectors to achieve specific goals. Agents can range from simple programs with a single-task focus to complex systems capable of making decisions based on a variety of inputs and conditions. Here are some common types of AI agents:\n\n1. **Simple Reflex Agents**: These agents operate based on a set of pre-defined rules or conditions. They do not have any memory of past actions or states. They use current perceptions to make decisions.\n\n2. **Model-Based Reflex Agents**: These agents maintain an internal model of the world, which they use to handle partially observable environments. They keep track of the state of the environment and adjust their actions accordingly.\n\n3. **Goal-Based Agents**: These agents act to achieve specific goals. They consider potential future states and make decisions that bring them closer to achieving their goals.\n\n4. **Utility-Based Agents**: In addition to goals, these agents take into consideration various "utilities" or preferences, which help them make preferable decisions when multiple options are available. They try to maximize their utility, balancing different factors like probability of success, risk, and reward.\n\n5. **Learning Agents**: These agents improve their performance over time by learning from their experiences. They typically consist of a learning element that modifies the agent\'s behavior, and a performance element that carries out actions.\n\nIn practice, AI agents can be found in many applications, from autonomous vehicles and personal assistants like Siri and Alexa to sophisticated game-playing systems like AlphaGo. Each type of agent is suited for different kinds of tasks and environments, depending on the complexity and the requirements of the problem domain.'

# %%
# using ChatOpenAI
from langchain_openai import ChatOpenAI
chat_model = ChatOpenAI(model="gpt-4o")
chat_response = chat_model.invoke("Explain the concept of Reinforcement Learning")
chat_response.content
# Out:
# 'Reinforcement Learning (RL) is a type of machine learning paradigm that is concerned with how agents should take actions in an environment to maximize some notion of cumulative reward. It is inspired by behavioral psychology and involves learning through interaction with an environment, where an agent has to make decisions and learn from the consequences in order to achieve the best possible outcome over time.\n\n### Key Concepts:\n\n1. **Agent and Environment**:\n    - **Agent**: The learner or decision-maker that interacts with the environment.\n    - **Environment**: Everything the agent interacts with, providing feedback in the form of rewards or penalties.\n\n2. **State**:\n   - A representation of the current situation of the agent in the environment. The state should contain all the relevant information required for decision-making.\n\n3. **Action**:\n   - Any decision or move the agent can make in the given state.\n\n4. **Reward**:\n   - A feedback signal that evaluates the immediate outcome of an action taken by the agent in a particular state. The goal of the agent is to maximize the cumulative reward over time.\n\n5. **Policy**:\n   - A strategy or a mapping from perceived states of the environment to actions to be taken when in those states. Policies can be deterministic (specific action for each state) or stochastic (probability distribution over actions for each state).\n\n6. **Value Function**:\n   - This function estimates how good it is for the agent to be in a given state or to perform a particular action in that state, in terms of future rewards. The most common are the State Value Function (V) and the Action Value Function (Q).\n\n7. **Exploration vs. Exploitation**:\n   - **Exploration**: The process of trying new actions to discover more about the environment.\n   - **Exploitation**: The process of using known knowledge to maximize the reward.\n\n8. **Model of the Environment** (not always used):\n   - A representation of the environment that predicts the next state and reward given a state and action. Not all RL algorithms use a model.\n\n### Learning Approaches:\n\n- **Model-Free vs. Model-Based**:\n  - **Model-Free**: The agent learns a policy or value function without an explicit model of the environment. Examples include Q-learning and Deep Q-Networks (DQN).\n  - **Model-Based**: The agent builds a model of the environment and uses it to plan actions. \n\n- **Temporal Difference Learning and Monte Carlo Methods**:\n  - **Temporal Difference Learning**: Updates estimates based in part on other learned estimates or the bootstrapping method, mixing ideas from Monte Carlo methods and dynamic programming.\n  - **Monte Carlo Methods**: Use the entire episode to compute rewards and update policies at the end.\n\n- **Deep Reinforcement Learning**:\n  - Uses neural networks to approximate value functions, policies, or models, enabling the tackling of complex problems with high-dimensional state spaces.\n\nRL has found success in various fields such as robotics, game playing (like AlphaGo), autonomous vehicles, and more, where decision-making under uncertainty and learning from interactions are essential.'

# %% [markdown]
# ### Streaming And Batch
#
# #### Streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write a 200 words paragraph about Agents in AI")
# Out:
# AIMessage(content='Agents in AI refer to autonomous entities capable of perceiving their environment through sensors and acting upon it using actuators to achieve specific goals. These agents range from simple reflex agents executing predefined rules to advanced learning agents that adapt based on experience. At the core of AI agents lies a decision-making algorithm that processes input data, evaluates possible actions, and selects the most appropriate response. This decision-making can involve rule-based systems, optimization algorithms, or machine learning models. \n\nReinforcement learning agents, in particular, have gained prominence due to their ability to learn optimal behaviors through trial and error, receiving feedback from their environment in the form of rewards or penalties. They have been successfully applied in various domains, including game-playing, robotics, and autonomous driving. Multi-agent systems, where several agents interact within a shared environment, open possibilities for complex problem-solving and are used in fields like distributed computing and collaborative robotics.\n\nThe development of ethical and safe AI agents is a growing area of research. Ensuring that agents behave in alignment with human values, avoid unintended harm, and make fair decisions are critical challenges. As AI technology advances, the role of agents will expand, enhancing their applications across industries and improving interactions between humans and machines.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 243, 'prompt_tokens': 17, 'total_tokens': 260, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CypZ5EbjTqmUdiJyYDpspKkXEA4os', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc99a-e74c-7e52-ac7a-11c659e404a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 243, 'total_tokens': 260, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# streaming
for chunk in model.stream("Write a 200 words paragraph about Agents in AI"):
    print(chunk.text, end='', flush=True)
# Out:
# Agents in artificial intelligence (AI) are autonomous entities that perceive their environment through sensors and act upon it using actuators to achieve specific goals. These agents are integral to AI systems and can range from simple software programs to complex robotic systems. The primary characteristic of an AI agent is its ability to make decisions based on the environment, which often involves utilizing algorithms and models to process inputs and predict outcomes. Agents can be categorized into different types, including reactive agents, which operate on current perceptions without considering history, and deliberative agents, which include planning to decide on actions. More sophisticated are hybrid agents that combine both reactive and deliberative features to enhance decision-making capabilities. Moreover, agents can be classified as either static or dynamic, depending on whether they function in a changeable environment. The dynamic nature of modern AI applications demands that agents can learn from their environments and improve over time, a characteristic often achieved through machine learning techniques. Their applications are vast, spanning from virtual assistants like Siri and Alexa to autonomous vehicles and sophisticated game bots, each exhibiting varying levels of intelligence and autonomy. The design and implementation of AI agents continue to evolve, driven by advancements in computing power, algorithms, and the ever-growing data availability.

# %%
for chunk in model.stream("Why do parrots have colored feathers?"):
    print(chunk.text, end="", flush=True)
# Out:
# Parrots have colored feathers for several reasons, primarily related to survival, communication, and mating:
#
# 1. **Camouflage**: In their natural habitats, which often include dense forests and jungles, the bright and varied colors of parrot feathers can help them blend into the surrounding bright foliage, flowers, and fruits. This camouflage can protect them from predators.
#
# 2. **Mating and Attraction**: Vivid colors can play a crucial role in attracting mates. During mating season, a parrot's colorful plumage can signal health and vitality to potential partners, suggesting good genes and a likelihood of producing strong offspring.
#
# 3. **Communication**: Parrots use their colorful feathers as a means of communication within their social groups. Different colors and patterns can convey different messages or emotions, aiding in social interactions.
#
# 4. **Species Recognition**: Bright colors and unique patterns can help individual parrots identify members of their own species, which is important for mating and social cohesion.
#
# 5. **Warning Signal**: In some cases, bright colors can serve as a warning to potential predators that the bird may be toxic or unpalatable, a strategy known as aposematism.
#
# Overall, the vibrant plumage of parrots is a result of evolutionary pressures that have shaped these birds to optimize their chances of survival and reproduction in their environments.

# %% [markdown]
# ### Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for several reasons, primarily related to their survival, mating, and communication.\n\n1. **Mating and Attraction**: Bright and vibrant feathers can help parrots attract mates. Many bird species rely on visual cues to select partners, and colorful plumage often signals good health and genetic fitness. In some species, the more vivid and diverse the colors, the more attractive the parrot is to potential mates.\n\n2. **Camouflage**: Although it might seem counterintuitive, the colorful plumage of parrots can serve as effective camouflage in their natural habitats, such as rainforests and woodlands. The mix of bright greens, reds, blues, and yellows can blend with the varied colors of leaves, flowers, fruits, and sunlight in these environments, helping to conceal the birds from predators.\n\n3. **Species and Individual Identification**: Colorful feathers can help parrots identify each other, recognize individuals, and maintain social structures within flocks. Specific color patterns and markings can indicate a parrot's species, age, or even social status within the group.\n\n4. **Communication**: Bright feathers can also be used for visual signals during communication. Parrots may use their plumage to display aggression, submission, or readiness to mate.\n\nThe evolution of these vibrant feathers is influenced by natural selection, where advantageous traits become more prevalent over generations. As a result, the striking colors of parrot feathers are a product of both ecological and social factors." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 299, 'prompt_tokens': 15, 'total_tokens': 314, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CypnE6ZeiPnyJGx3xSXdHR2OJZTBO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019bc9a8-4931-7961-ad43-3a3064d0a6b0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 299, 'total_tokens': 314, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='Airplanes fly by generating lift, which is produced by the wings moving through the air. The principles of flight are grounded in the physics described by Bernoulli’s principle and Newton’s third law of motion. Here’s a simplified explanation of the process:\n\n1. **Thrust**: Airplanes have engines that provide the force needed to move them forward, known as thrust. This can be achieved through jet engines or propellers. The engines accelerate the plane along the runway until it reaches a speed capable of generating sufficient lift.\n\n2. **Lift**: The wings of an airplane are shaped to have a special airfoil design. When the airplane moves forward, air flows faster over the top of the wing and slower underneath. This creates a difference in pressure: the pressure on top of the wing is lower than the pressure below the wing, generating lift. According to Bernoulli’s principle, this difference in pressure results in an upward force, lifting the plane into the air.\n\n3. **Drag**: As the airplane moves through the air, it encounters resistance known as drag. This force opposes the forward motion of the airplane. Engineers design aircraft to be as aerodynamic as possible to minimize drag.\n\n4. **Weight**: The weight of the airplane acts downward due to gravity. For the airplane to climb and cruise at altitude, the lift must be greater than the weight. \n\nControl of the airplane is achieved through various movable parts on the wings and tail, such as ailerons, elevators, and rudders, which can adjust the lift and direction of the airplane. The balance and management of thrust, lift, drag, and weight allow the airplane to climb, cruise, descend, and maneuver safely through the air.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 348, 'prompt_tokens': 12, 'total_tokens': 360, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CypnEAhMVNor5EGyUXqbzc3dHUJ4B', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019bc9a8-4933-7a11-bae3-a5e3a3aa540a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 348, 'total_tokens': 360, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='Quantum computing is a type of computation that harnesses the principles of quantum mechanics to process information in fundamentally different ways than classical computers. Classical computers use bits as the smallest unit of information, which can be either a 0 or a 1. In contrast, quantum computers use quantum bits, or qubits, which can exist in multiple states simultaneously due to a property called superposition.\n\nKey features of quantum computing include:\n\n1. **Superposition**: Qubits can represent both 0 and 1 at the same time, allowing quantum computers to process a vast number of possibilities simultaneously.\n\n2. **Entanglement**: Qubits can become entangled, meaning the state of one qubit can depend on the state of another, even over large distances. This phenomenon enables quantum computers to perform certain calculations much more efficiently than classical computers.\n\n3. **Interference**: By carefully combining different quantum states, quantum computers can enhance the probability of getting the correct answer and reduce the probability of incorrect ones.\n\nQuantum computers are especially well-suited for tasks such as factoring large numbers, simulating quantum systems, optimizing complex systems, and solving certain algorithms more efficiently than classical computers. However, building a practical, large-scale quantum computer poses significant technical challenges, including error correction, qubit fidelity, and maintaining coherence. Despite these challenges, quantum computing holds promise for revolutionizing fields such as cryptography, materials science, and complex problem-solving.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 290, 'prompt_tokens': 12, 'total_tokens': 302, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CypnEhaETPRAqW7wTYMiGwN1zd9Hb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019bc9a8-4934-79f1-9210-1e04258e6903-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 290, 'total_tokens': 302, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content='Parrots have colorful feathers for several reasons, primarily related to survival and reproduction:\n\n1. **Mate Attraction:** Brightly colored feathers are often used to attract potential mates. In many species of parrots, having vibrant plumage is a sign of health and genetic fitness, making those individuals more desirable to mates.\n\n2. **Species and Individual Recognition:** Colorful feathers can help parrots recognize members of their own species and even individual birds. This is important for social interactions and forming bonds within flocks.\n\n3. **Camouflage:** While it may seem counterintuitive, the bright feathers can serve as camouflage in the colorful environments where many parrots live, such as tropical forests. The multitude of colors can help them blend in with flowers, fruits, and foliage.\n\n4. **Communication:** Parrots use their plumage to communicate with each other. Changes in posture or the display of different feather colors can convey various signals, such as warnings or courtship displays.\n\n5. **Thermoregulation and Protection:** Feathers can also play a role in thermoregulation and protection from the elements. Some colors can help with deflecting sunlight or providing warmth, while others may offer protection against abrasion and parasites.\n\nOverall, the beautiful colors of parrot feathers are the result of a complex interplay of evolutionary factors driving survival and reproduction.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 268, 'prompt_tokens': 15, 'total_tokens': 283, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CypnYakUtX9y9NQOWUNviaiYGti8r', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc9a8-9a98-7263-870a-25f8ab168221-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 268, 'total_tokens': 283, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content="Airplanes fly by utilizing the principles of aerodynamics, which involve four main forces: lift, weight, thrust, and drag. Here's a breakdown of how these forces work together to enable flight:\n\n1. **Lift**: This upward force is crucial for flight and is generated by the wings of the airplane. The wings are designed with an airfoil shape, which means they have a curved upper surface and a flatter lower surface. As the airplane moves forward, air flows over and under the wings. According to Bernoulli's principle and the angle of attack, the pressure on the upper surface of the wing is lower than that on the bottom, creating lift.\n\n2. **Weight**: This is the force due to gravity pulling the airplane toward the Earth. For an airplane to ascend and stay in the air, the lift must counteract the weight.\n\n3. **Thrust**: This forward force is produced by the airplane's engines. Thrust propels the airplane forward, allowing air to flow over the wings and generate lift. The amount of thrust must at least match the drag for the airplane to maintain speed and lift.\n\n4. **Drag**: This is the aerodynamic resistance the airplane encounters as it moves through the air. It acts opposite to the direction of thrust. Drag is influenced by factors such as the shape and size of the airplane, as well as air density and speed.\n\nIn practice, for an airplane to take off, the thrust from the engines must be greater than the drag, and the lift must be greater than the weight. Once airborne, pilots adjust the balance of these forces to climb, descend, and maneuver during flight. Control surfaces like ailerons, elevators, and rudders help manage the airplane's orientation and stability by controlling roll, pitch, and yaw, respectively.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 364, 'prompt_tokens': 12, 'total_tokens': 376, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CypnYZlDIH7ZTL0goBw5Ph9yfubao', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc9a8-9a99-71a0-abc9-ebe5e5a6e386-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 364, 'total_tokens': 376, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='Quantum computing is a type of computation that leverages the principles of quantum mechanics to process information. Unlike classical computers, which use bits as the smallest unit of information (represented as either 0 or 1), quantum computers use quantum bits, or qubits. Qubits take advantage of quantum properties such as superposition and entanglement.\n\n- **Superposition** allows qubits to exist in multiple states (i.e., 0 and 1) simultaneously. This capability enables quantum computers to process a vast amount of possibilities at once, which can significantly speed up certain types of computations.\n\n- **Entanglement** is a phenomenon where qubits become interconnected such that the state of one qubit can depend on the state of another, regardless of the distance between them. This property can be used to perform complex operations more efficiently than classical computers can.\n\nThese features enable quantum computers to solve specific problems much faster than classical computers. For example, they have the potential to revolutionize fields such as cryptography, optimization, drug discovery, and materials science by solving problems that are currently intractable for classical computers. However, building stable and scalable quantum computers is highly challenging due to issues such as qubit coherence and error rates, and quantum computing is still largely in the experimental and developmental stage.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 260, 'prompt_tokens': 12, 'total_tokens': 272, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CypnYSQ8QXFsQOaOUEnB6QCtO8jwb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bc9a8-9a9a-72d2-8013-4ed8e96b8172-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 260, 'total_tokens': 272, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
